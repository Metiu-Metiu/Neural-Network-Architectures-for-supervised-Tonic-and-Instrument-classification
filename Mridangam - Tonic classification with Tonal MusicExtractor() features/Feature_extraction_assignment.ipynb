# %% [markdown]
# ## Mridangam tonic classification task using Essentia Music Extractor.
# From mirdata 0.3.7 documentation, specifically for the mridangam_stroke dataset, we can see that the following annotations are available for each track in the dataset;
# TrackID
# AuthorName
# StrokeName
# Tonic
# InstanceNum
#
# Since a classification has already been made on StrokeName, this time I am performing it on the Tonic annotation

# %%
#If not installed, install Essentia. 
# This cell is for running the notebook in Colab
import importlib.util
if importlib.util.find_spec('essentia') is None:
    # !pip install essentia

# !pip install mirdata
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting essentia
#   Downloading essentia-2.1b6.dev858-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from essentia) (1.15.0)
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.8/dist-packages (from essentia) (1.21.6)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (from essentia) (6.0)
# Installing collected packages: essentia
# Successfully installed essentia-2.1b6.dev858
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mirdata
#   Downloading mirdata-0.3.7-py3-none-any.whl (14.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.9/14.9 MB 31.7 MB/s eta 0:00:00
# Collecting jams
#   Downloading jams-0.3.4.tar.gz (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.3/51.3 KB 7.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.8/dist-packages (from mirdata) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from mirdata) (2.25.1)
# Collecting pretty-midi>=0.2.8
#   Downloading pretty_midi-0.2.9.tar.gz (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 59.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from mirdata) (4.64.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (from mirdata) (6.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from mirdata) (1.7.3)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from mirdata) (1.3.5)
# Requirement already satisfied: h5py>=2.10.0 in /usr/local/lib/python3.8/dist-packages (from mirdata) (3.1.0)
# Requirement already satisfied: librosa>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from mirdata) (0.8.1)
# Collecting Deprecated>=1.2.13
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: chardet in /usr/local/lib/python3.8/dist-packages (from mirdata) (4.0.0)
# Requirement already satisfied: smart-open>=5.0.0 in /usr/local/lib/python3.8/dist-packages (from mirdata) (6.3.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.8/dist-packages (from Deprecated>=1.2.13->mirdata) (1.14.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from librosa>=0.8.0->mirdata) (21.3)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from librosa>=0.8.0->mirdata) (1.0.2)
# Requirement already satisfied: numba>=0.43.0 in /usr/local/lib/python3.8/dist-packages (from librosa>=0.8.0->mirdata) (0.56.4)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from librosa>=0.8.0->mirdata) (3.0.0)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.8/dist-packages (from librosa>=0.8.0->mirdata) (1.6.0)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from librosa>=0.8.0->mirdata) (4.4.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.8/dist-packages (from librosa>=0.8.0->mirdata) (1.2.0)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.8/dist-packages (from librosa>=0.8.0->mirdata) (0.11.0)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.8/dist-packages (from librosa>=0.8.0->mirdata) (0.4.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.0->mirdata) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.0->mirdata) (2022.7)
# Collecting mido>=1.1.16
#   Downloading mido-1.2.10-py2.py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 KB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from pretty-midi>=0.2.8->mirdata) (1.15.0)
# Requirement already satisfied: sortedcontainers>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from jams->mirdata) (2.4.0)
# Requirement already satisfied: jsonschema>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from jams->mirdata) (4.3.3)
# Collecting mir_eval>=0.5
#   Downloading mir_eval-0.7.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.7/90.7 KB 12.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->mirdata) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->mirdata) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->mirdata) (2.10)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0.0->jams->mirdata) (5.10.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0.0->jams->mirdata) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0.0->jams->mirdata) (22.2.0)
# Requirement already satisfied: future in /usr/local/lib/python3.8/dist-packages (from mir_eval>=0.5->jams->mirdata) (0.16.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from numba>=0.43.0->librosa>=0.8.0->mirdata) (6.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from numba>=0.43.0->librosa>=0.8.0->mirdata) (57.4.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.8/dist-packages (from numba>=0.43.0->librosa>=0.8.0->mirdata) (0.39.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->librosa>=0.8.0->mirdata) (3.0.9)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.8/dist-packages (from pooch>=1.0->librosa>=0.8.0->mirdata) (1.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa>=0.8.0->mirdata) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.8/dist-packages (from soundfile>=0.10.2->librosa>=0.8.0->mirdata) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa>=0.8.0->mirdata) (2.21)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=1.4.0->jsonschema>=3.0.0->jams->mirdata) (3.11.0)
# Building wheels for collected packages: pretty-midi, jams, mir_eval
#   Building wheel for pretty-midi (setup.py) ... done
#   Created wheel for pretty-midi: filename=pretty_midi-0.2.9-py3-none-any.whl size=5591954 sha256=1c99e90a11375843ff1010a93aa20a44a5108b892ed072543893943f7bd91816
#   Stored in directory: /root/.cache/pip/wheels/2a/5a/e3/30eeb9a99350f3f7e21258fcb132743eef1a4f49b3505e76b6
#   Building wheel for jams (setup.py) ... done
#   Created wheel for jams: filename=jams-0.3.4-py3-none-any.whl size=64922 sha256=d91b9654a60975193c5bb76f33bff199eea44695ebb2439b56b984ba91ac188d
#   Stored in directory: /root/.cache/pip/wheels/e4/20/61/289b8740c6808be5cebe5ec984968a12b598f32af229bb284b
#   Building wheel for mir_eval (setup.py) ... done
#   Created wheel for mir_eval: filename=mir_eval-0.7-py3-none-any.whl size=100720 sha256=d1c9863dadea4c1205aad587394389bc4d10254a9112c62275eb89c1529ae82f
#   Stored in directory: /root/.cache/pip/wheels/20/53/83/1d50d15a666140d53eda589db005f7cb53b739c7e54711f51f
# Successfully built pretty-midi jams mir_eval
# Installing collected packages: mido, pretty-midi, Deprecated, mir_eval, jams, mirdata
# Successfully installed Deprecated-1.2.13 jams-0.3.4 mido-1.2.10 mir_eval-0.7 mirdata-0.3.7 pretty-midi-0.2.9
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (1.3.5)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from pandas) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas) (2022.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
#Basic imports
import os
import matplotlib.pyplot as plt
import numpy as np

# Imports to support MIR
import mirdata
import essentia.standard as ess
import pandas as pd

# %% [markdown]
# ## Data processing

# %% [markdown]
# We initialize Mridangam stroke a collection of 7162 audio examples of individual strokes of the Mridangam in various tonics. The dataset comprises of 10 different strokes played on Mridangams with 6 different tonic values.
#
# In this experiment we predict 6 tonic classes, which are;
# B	C	C#	D	D#	E ; tagged as ;
# Tonic = {B, C, Csh, D, Dsh, E}
#
# (from https://compmusic.upf.edu/mridangam-stroke-dataset)

# %%
mridangam = mirdata.initialize("mridangam_stroke")

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
#This cell downloads and validates the mridangam dataset
mridangam.download()  # download the dataset
#mridangam_stroke.validate()  # validate that all the expected files are there
# Out:
# 124MB [04:12, 516kB/s]

# %%
mridangam_ids = mridangam.track_ids  # Load Mridangam IDs

'''
mridangam_data is a list of tracks (https://mirdata.readthedocs.io/en/stable/source/mirdata.html#mirdata.datasets.mridangam_stroke.Track)
with variables like stroke_name (the used in the provided example notebook),
tonic (the one I am using now), ecc.
'''
mridangam_data = mridangam.load_tracks()  # Load Mridangam data

mridangam_data[mridangam_ids[0]]  # Visualize a single track
# Out:
# Track(
#   audio_path="/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224030__akshaylaya__bheem-b-001.wav",
#   stroke_name="bheem",
#   tonic="B",
#   track_id="224030",
#   audio: The track's audio
#
#         Returns,
# )

# %%
# Get complete list of different TONICS
stroke_tonics = []
for i in mridangam_ids:
    stroke_tonics.append(mridangam_data[i].tonic)
stroke_tonics = np.unique(stroke_tonics)
# converting the list into a set of strings (unordered, with no repetitions -unique data-)
print(stroke_tonics)
# Out:
# ['B' 'C' 'C#' 'D' 'D#' 'E']

# %%
# You can create a dictionary using tonics as keys and audio paths as values
tonics_dict = {item: [] for item in stroke_tonics}
for i in mridangam_ids:
    tonics_dict[mridangam_data[i].tonic].append(mridangam_data[i].audio_path)

# tonics_dict['B'] # print example of list of values (audio paths) for the B key
# print(tonics_dict.items())
for key in tonics_dict.keys():
  print(f'Audio paths of files labelled with tonic {key}')
  print(tonics_dict.get(key))
# Out:
# Audio paths of files labelled with tonic B
# ['/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224030__akshaylaya__bheem-b-001.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224031__akshaylaya__bheem-b-002.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224032__akshaylaya__bheem-b-003.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224033__akshaylaya__bheem-b-004.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224034__akshaylaya__bheem-b-005.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224035__akshaylaya__cha-b-001.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224036__akshaylaya__cha-b-002.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224037__akshaylaya__cha-b-003.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224038__akshaylaya__cha-b-004.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224039__akshaylaya__cha-b-005.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224040__akshaylaya__cha-b-006.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224041__akshaylaya__cha-b-007.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224042__akshaylaya__cha-b-008.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224043__akshaylaya__cha-b-009.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224044__akshaylaya__cha-b-010.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224045__akshaylaya__cha-b-011.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224046__akshaylaya__cha-b-012.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224047__akshaylaya__cha-b-013.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224048__akshaylaya__cha-b-014.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224049__akshaylaya__cha-b-015.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224050__akshaylaya__cha-b-016.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224051__akshaylaya__cha-b-017.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224052__akshaylaya__cha-b-018.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224053__akshaylaya__cha-b-019.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224054__akshaylaya__cha-b-020.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224055__akshaylaya__cha-b-021.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224056__akshaylaya__cha-b-022.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224057__akshaylaya__cha-b-023.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224058__akshaylaya__cha-b-024.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224059__akshaylaya__cha-b-025.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224060__akshaylaya__cha-b-026.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224061__akshaylaya__cha-b-027.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224062__akshaylaya__cha-b-028.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224063__akshaylaya__cha-b-029.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224064__akshaylaya__cha-b-030.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224065__akshaylaya__cha-b-031.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224066__akshaylaya__cha-b-032.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224067__akshaylaya__cha-b-033.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224069__akshaylaya__cha-b-035.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224070__akshaylaya__cha-b-036.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/B/224071__akshaylaya__cha-b-037.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke ...
# Audio paths of files labelled with tonic C
# ['/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225356__akshaylaya__bheem-c-001.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225357__akshaylaya__bheem-c-002.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225358__akshaylaya__bheem-c-003.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225359__akshaylaya__cha-c-001.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225360__akshaylaya__cha-c-002.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225361__akshaylaya__cha-c-003.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225362__akshaylaya__cha-c-004.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225363__akshaylaya__cha-c-005.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225364__akshaylaya__cha-c-006.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225365__akshaylaya__cha-c-007.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225366__akshaylaya__cha-c-008.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225367__akshaylaya__cha-c-009.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225368__akshaylaya__cha-c-010.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225369__akshaylaya__cha-c-011.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225370__akshaylaya__cha-c-012.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225371__akshaylaya__cha-c-013.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225372__akshaylaya__cha-c-014.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225373__akshaylaya__cha-c-015.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225374__akshaylaya__cha-c-016.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225375__akshaylaya__cha-c-017.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225376__akshaylaya__cha-c-018.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225377__akshaylaya__cha-c-019.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225378__akshaylaya__cha-c-020.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225379__akshaylaya__cha-c-021.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225380__akshaylaya__cha-c-022.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225381__akshaylaya__cha-c-023.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225382__akshaylaya__cha-c-024.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225383__akshaylaya__cha-c-025.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225384__akshaylaya__cha-c-026.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225385__akshaylaya__cha-c-027.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225386__akshaylaya__cha-c-028.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225387__akshaylaya__cha-c-029.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225388__akshaylaya__cha-c-030.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225389__akshaylaya__cha-c-031.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225390__akshaylaya__cha-c-032.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225391__akshaylaya__cha-c-033.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225392__akshaylaya__cha-c-034.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225393__akshaylaya__cha-c-035.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225394__akshaylaya__cha-c-036.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225395__akshaylaya__cha-c-037.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C/225396__akshaylaya__cha-c-038.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5 ...
# Audio paths of files labelled with tonic C#
# ['/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226488__akshaylaya__bheem-csh-001.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226489__akshaylaya__cha-csh-001.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226490__akshaylaya__cha-csh-002.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226491__akshaylaya__cha-csh-003.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226492__akshaylaya__cha-csh-004.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226493__akshaylaya__cha-csh-005.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226494__akshaylaya__cha-csh-006.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226495__akshaylaya__cha-csh-007.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226496__akshaylaya__cha-csh-008.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226497__akshaylaya__cha-csh-009.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226498__akshaylaya__cha-csh-010.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226499__akshaylaya__cha-csh-011.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226500__akshaylaya__cha-csh-012.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226501__akshaylaya__cha-csh-013.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226502__akshaylaya__cha-csh-014.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226503__akshaylaya__cha-csh-015.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226504__akshaylaya__cha-csh-016.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226505__akshaylaya__cha-csh-017.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226506__akshaylaya__cha-csh-018.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226507__akshaylaya__cha-csh-019.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226508__akshaylaya__cha-csh-020.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226509__akshaylaya__cha-csh-021.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226510__akshaylaya__cha-csh-022.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226511__akshaylaya__cha-csh-023.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226512__akshaylaya__cha-csh-024.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226513__akshaylaya__cha-csh-025.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226514__akshaylaya__cha-csh-026.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226515__akshaylaya__cha-csh-027.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226516__akshaylaya__cha-csh-028.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226517__akshaylaya__cha-csh-029.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226518__akshaylaya__cha-csh-030.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226519__akshaylaya__cha-csh-031.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226520__akshaylaya__cha-csh-032.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226522__akshaylaya__cha-csh-034.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226523__akshaylaya__cha-csh-035.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226524__akshaylaya__cha-csh-036.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226525__akshaylaya__cha-csh-037.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226526__akshaylaya__cha-csh-038.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226528__akshaylaya__cha-csh-040.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/C#/226529__akshaylaya__cha-csh-041.wav', '/root/mir_datasets/mridangam_stroke/ ...
# Audio paths of files labelled with tonic D
# ['/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227687__akshaylaya__cha-d-001.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227688__akshaylaya__cha-d-002.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227690__akshaylaya__cha-d-004.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227691__akshaylaya__cha-d-005.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227692__akshaylaya__cha-d-006.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227693__akshaylaya__cha-d-007.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227694__akshaylaya__cha-d-008.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227695__akshaylaya__cha-d-009.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227696__akshaylaya__cha-d-010.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227697__akshaylaya__cha-d-011.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227698__akshaylaya__cha-d-012.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227699__akshaylaya__cha-d-013.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227700__akshaylaya__cha-d-014.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227701__akshaylaya__cha-d-015.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227702__akshaylaya__cha-d-016.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227703__akshaylaya__cha-d-017.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227704__akshaylaya__cha-d-018.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227705__akshaylaya__cha-d-019.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227706__akshaylaya__cha-d-020.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227707__akshaylaya__cha-d-021.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227708__akshaylaya__cha-d-022.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227709__akshaylaya__cha-d-023.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227710__akshaylaya__cha-d-024.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227711__akshaylaya__cha-d-025.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227712__akshaylaya__cha-d-026.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227713__akshaylaya__cha-d-027.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227714__akshaylaya__cha-d-028.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227715__akshaylaya__cha-d-029.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227716__akshaylaya__cha-d-030.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227717__akshaylaya__cha-d-031.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227718__akshaylaya__cha-d-032.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227719__akshaylaya__cha-d-033.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227720__akshaylaya__cha-d-034.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227721__akshaylaya__cha-d-035.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227722__akshaylaya__cha-d-036.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227723__akshaylaya__cha-d-037.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227724__akshaylaya__cha-d-038.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227725__akshaylaya__cha-d-039.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227726__akshaylaya__cha-d-040.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227727__akshaylaya__cha-d-041.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227730__akshaylaya__cha-d-044.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D/227 ...
# Audio paths of files labelled with tonic D#
# ['/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228625__akshaylaya__bheem-dsh-001.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228626__akshaylaya__bheem-dsh-002.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228627__akshaylaya__bheem-dsh-003.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228628__akshaylaya__bheem-dsh-004.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228629__akshaylaya__bheem-dsh-005.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228630__akshaylaya__bheem-dsh-006.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228631__akshaylaya__bheem-dsh-007.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228632__akshaylaya__bheem-dsh-008.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228633__akshaylaya__bheem-dsh-009.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228634__akshaylaya__bheem-dsh-010.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228635__akshaylaya__bheem-dsh-011.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228636__akshaylaya__bheem-dsh-012.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228637__akshaylaya__bheem-dsh-013.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228638__akshaylaya__bheem-dsh-014.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228639__akshaylaya__bheem-dsh-015.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228640__akshaylaya__cha-dsh-001.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228641__akshaylaya__cha-dsh-002.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228642__akshaylaya__cha-dsh-003.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228643__akshaylaya__cha-dsh-004.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228644__akshaylaya__cha-dsh-005.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228645__akshaylaya__cha-dsh-006.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228646__akshaylaya__cha-dsh-007.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228647__akshaylaya__cha-dsh-008.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228648__akshaylaya__cha-dsh-009.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228649__akshaylaya__cha-dsh-010.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228650__akshaylaya__cha-dsh-011.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228651__akshaylaya__cha-dsh-012.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228652__akshaylaya__cha-dsh-013.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228653__akshaylaya__cha-dsh-014.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228654__akshaylaya__cha-dsh-015.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228655__akshaylaya__cha-dsh-016.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228656__akshaylaya__cha-dsh-017.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228657__akshaylaya__cha-dsh-018.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228658__akshaylaya__cha-dsh-019.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228659__akshaylaya__cha-dsh-020.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228660__akshaylaya__cha-dsh-021.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228661__akshaylaya__cha-dsh-022.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228662__akshaylaya__cha-dsh-023.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228663__akshaylaya__cha-dsh-024.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/D#/228664__akshaylaya__cha-dsh-025.wav', '/root/mi ...
# Audio paths of files labelled with tonic E
# ['/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230136__akshaylaya__bheem-e-001.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230137__akshaylaya__bheem-e-002.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230138__akshaylaya__bheem-e-003.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230139__akshaylaya__bheem-e-004.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230140__akshaylaya__bheem-e-005.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230141__akshaylaya__bheem-e-006.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230142__akshaylaya__bheem-e-007.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230143__akshaylaya__bheem-e-008.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230144__akshaylaya__bheem-e-009.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230145__akshaylaya__bheem-e-010.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230146__akshaylaya__bheem-e-011.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230147__akshaylaya__bheem-e-012.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230148__akshaylaya__bheem-e-013.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230149__akshaylaya__bheem-e-014.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230150__akshaylaya__bheem-e-015.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230151__akshaylaya__bheem-e-016.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230152__akshaylaya__bheem-e-017.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230153__akshaylaya__bheem-e-018.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230154__akshaylaya__bheem-e-019.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230155__akshaylaya__bheem-e-020.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230156__akshaylaya__bheem-e-021.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230157__akshaylaya__bheem-e-022.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230158__akshaylaya__bheem-e-023.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230159__akshaylaya__bheem-e-024.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230160__akshaylaya__bheem-e-025.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230161__akshaylaya__cha-e-001.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230162__akshaylaya__cha-e-002.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230163__akshaylaya__cha-e-003.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230164__akshaylaya__cha-e-004.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230165__akshaylaya__cha-e-005.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230166__akshaylaya__cha-e-006.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230167__akshaylaya__cha-e-007.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230168__akshaylaya__cha-e-008.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230169__akshaylaya__cha-e-009.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230170__akshaylaya__cha-e-010.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230171__akshaylaya__cha-e-011.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230172__akshaylaya__cha-e-012.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230173__akshaylaya__cha-e-013.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230174__akshaylaya__cha-e-014.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230175__akshaylaya__cha-e-015.wav', '/root/mir_datasets/mridangam_stroke/mridangam_stroke_1.5/E/230176__akshaylaya__cha-e-016.wav', '/root/mir_da ...

# %%
# Raw-data preprocess analysis parameters
_, fs = mridangam_data[mridangam_ids[0]].audio

num_tonics = len(tonics_dict.keys())
print("Plot waveforms of random samples of each tonic type...")
plt.figure(1, figsize=(5 * num_tonics, 3))
file_ind_inlist = 0 # 0: let's take the first file in the list for sample plots
for i, tonic in enumerate(tonics_dict.keys()):
    sample_file = tonics_dict[tonic][file_ind_inlist]
    x = ess.MonoLoader(filename = sample_file, sampleRate = fs)()
    
    plt.subplot(1,num_tonics,(i+1))
    plt.plot(x)
    plt.title(tonic)
# Out:
# Plot waveforms of random samples of each tonic type...

# %% [markdown]
# ## Preprocessing of raw data: Segmentation, splitting, alignment,...

# %% [markdown]
# While common preprocessing steps (such as amplitude normalisation) exist, there is often some dataset and task specific preprocessing tasks required for grouping, cleaning, and format change.
#
# In the downloaded dataset, recordings include a sequence of isolated notes played in sequence which could be split into isolated notes. We would like to investigate the option of splitting using a fixed energy threshold (which would help us seperate notes using the silence regions). Let's define a function to perform this operation and visualize some samples to observe the effectiveness of it.

# %%
# Raw-data preprocess analysis parameters
windowSize = 1024
hopSize = 512
NRG_threshold_ratio = 0.005 #threshold expressed as ratio with respect to the maximum value
#Let's put in a container to be able to use as a single argument in function calls
params = {"fs":fs, "windowSize":windowSize, "hopSize":hopSize, "NRG_threshold_ratio": NRG_threshold_ratio}

# %%
#Function definition
def split_file(filename, params):
    '''Function to define split boundaries based on a fixed energy threshold
    '''
    x = ess.MonoLoader(filename = filename, sampleRate = fs)()
    NRG = [];
    #Main windowing and feature extraction loop
    for frame in ess.FrameGenerator(x, frameSize = windowSize, hopSize = hopSize, startFromZero = True):
        NRG.append(ess.Energy()(frame))
    NRG = np.array(NRG)
    NRG = NRG / np.max(NRG)
    
    #Applying energy threshold to decide wave split boundaries
    split_decision_func = np.zeros_like(NRG)
    split_decision_func[NRG > NRG_threshold_ratio] = 1
    #Setting segment boundaries
    #Inserting a zero at the beginning since we will decide the transitions using a diff function
    split_decision_func = np.insert(split_decision_func, 0, 0)
    diff_split_decision = np.diff(split_decision_func)
    #Start indexes: transition from 0 to 1
    start_indexes = np.nonzero(diff_split_decision > 0)[0] * hopSize
    #Stop indexes: transition from 1 to 0
    stop_indexes = np.nonzero(diff_split_decision < 0)[0] * hopSize
    return (x, NRG, split_decision_func, start_indexes, stop_indexes)

# %%
num_tonics = len(stroke_tonics)
print("Sample plots for waveform versus energy and splits based on energy threshold")

file_indexes = [1]
for file_ind_inlist in file_indexes:
    plt.figure(file_ind_inlist, figsize=(5 * num_tonics, 3))
    for i, stroke in enumerate(tonics_dict.keys()):
        sample_file = tonics_dict[stroke][file_ind_inlist]
        (x, NRG, split_decision_func, start_indexes, stop_indexes) = split_file(sample_file, params)
        #Plotting functions for checking the split decisions
        plt.subplot(1,num_tonics,(i+1))
        plt.title(stroke)
        plt.plot(x, label = 'sound waveform')
        plt.plot(np.arange(NRG.size) * hopSize, NRG, 'g', label = 'NRG')
        plt.plot(np.arange(split_decision_func.size) * hopSize, split_decision_func,'r', label = 'split function')
        plt.vlines(start_indexes, ymin = -0.5, ymax = 0, colors='b', linestyles='solid', label='Segment start')
        plt.vlines(stop_indexes, ymin = -0.5, ymax = 0, colors='k', linestyles='dashed', label='Segment stop')

plt.legend(loc="best");
# Out:
# Sample plots for waveform versus energy and splits based on energy threshold

# %%
main_data_dir = 'sample_data'
if not os.path.exists(main_data_dir): #creating the directory
    os.mkdir(main_data_dir)
segments_dir = os.path.join(main_data_dir,'segments')
if not os.path.exists(segments_dir): #creating the directory
    os.mkdir(segments_dir)

segment_files = []
for tonic, files in tonics_dict.items():
    for sample_file in files:
        #Get file id
        tonic_id =  sample_file.split('__')[-1].split('.')[0]
        x = ess.MonoLoader(filename = sample_file, sampleRate = fs)()
        (x, NRG, split_decision_func, start_indexes, stop_indexes) = split_file(sample_file, params)
        #Croping segments
        for start, stop in zip(start_indexes, stop_indexes):
            x_seg = x[start: stop]
            #Final check for amplitude (to avoid silent segments selection due to noise in split function)
            if(np.max(np.abs(x_seg)) > 0.05):
                #Amplitude normalisation
                x_seg = x_seg / np.max(np.abs(x_seg))
                filename = os.path.join(segments_dir, tonic_id + '.wav')
                ess.MonoWriter(filename = filename, format = 'wav', sampleRate = fs)(x_seg)
                segment_files.append(filename)

print(len(segment_files),'segment files created')
# Out:
# 6854 segment files created

# %%
#If required, you can use this cell to delete all files in a given folder
def delete_files_in_dir(dir_name):
    '''Deleting all files in a directory
    '''
    for root, dirs, files in os.walk(dir_name):
        for file in files:
            file_name = os.path.join(root,file)
            os.remove(file_name);print(file_name, 'removed');

#delete_files_in_dir(segments_dir)

# %% [markdown]
# ## Feature extraction
#
# Let's compute a list of common features for each of the files and form a data frame including features and categories. We will be using the [MusicExtractor function of Essentia](https://essentia.upf.edu/documentation/reference/std_MusicExtractor.html) that would compute a large number of features commonly used in MIR literature.
#
# Essentia-MusicExtractor extracts a large number of features. For simplicity, let's only keep low-level descriptors which are represented with a single scalar value as our feature set and discard other features.

# %%
# Print descriptors to be considered
# this time I am changing the essentia.MusicExtractor() parameters in order to try
# to improve the accuracy of my classification, by choosing
# "tonal" features to be extracted
'''
From Essentia's MusicExtractor's docs;

tonal:
    frameSize: 4096
    hopSize: 2048
    zeroPadding: 0
    windowType: blackmanharris62
    silentFrames: noise
    stats: ["mean", "var", "median", "min", "max"]
'''
features, features_frames = ess.MusicExtractor(tonalStats = ["mean", "var", "median", "min", "max"])(mridangam_data['224030'].audio_path)

scalar_tonal_descriptors = [descriptor for descriptor in features.descriptorNames() if 'tonal' in descriptor and isinstance(features[descriptor], float)]
print("Subset of features to be considered:\n",scalar_tonal_descriptors)
# Out:
# Subset of features to be considered:
#  ['tonal.chords_changes_rate', 'tonal.chords_number_rate', 'tonal.chords_strength.max', 'tonal.chords_strength.mean', 'tonal.chords_strength.median', 'tonal.chords_strength.min', 'tonal.chords_strength.var', 'tonal.hpcp_crest.max', 'tonal.hpcp_crest.mean', 'tonal.hpcp_crest.median', 'tonal.hpcp_crest.min', 'tonal.hpcp_crest.var', 'tonal.hpcp_entropy.max', 'tonal.hpcp_entropy.mean', 'tonal.hpcp_entropy.median', 'tonal.hpcp_entropy.min', 'tonal.hpcp_entropy.var', 'tonal.key_edma.strength', 'tonal.key_krumhansl.strength', 'tonal.key_temperley.strength', 'tonal.tuning_diatonic_strength', 'tonal.tuning_equal_tempered_deviation', 'tonal.tuning_frequency', 'tonal.tuning_nontempered_energy_ratio']

# %% [markdown]
# Running musicextractor for all files, keeping a subset of features, writing to an output file: data.csv

# %%
# Extracting features and writing in data.csv file in the segments folder
#  each line in the data.csv file represents a sample with features and the class information as the last element
data_file = 'sample_data/data.csv'
file_count = 0
with open(data_file, 'w') as writer:
    #adding column names as the first line in csv
    line2write = ','.join(scalar_tonal_descriptors + ['tonic']).replace('tonal.','') + '\n'
    writer.write(line2write)
    for filename in segment_files:
        file_count +=1
        if file_count % 20 == 0: #print name of a file every 20 files
            print(file_count, "files processed, current file: ", filename)

        #Compute and write features for file
        features, features_frames = ess.MusicExtractor(tonalStats = ["mean", "var", "median", "min", "max"])(filename)
        selected_features = [features[descriptor] for descriptor in scalar_tonal_descriptors]
        # the variable "label" holds a string containing the name of the tonic
        # we use str.split() python built-in function to "extract" the string from the audio file name
        # https://docs.python.org/3/library/stdtypes.html?highlight=str%20split#str.split
        # I modified this line in order to format properly the tonic name rather than the stroke name
        label = filename.split('-')[1]
        line2write = str(selected_features)[1:-1] + ',' + label + '\n'
        writer.write(line2write)
print("A total of ", file_count, "files processed")
# Out:
# 20 files processed, current file:  sample_data/segments/cha-b-017.wav
# 40 files processed, current file:  sample_data/segments/cha-b-039.wav
# 60 files processed, current file:  sample_data/segments/dheem-b-005.wav
# 80 files processed, current file:  sample_data/segments/dheem-b-026.wav
# 100 files processed, current file:  sample_data/segments/dheem-b-046.wav
# 120 files processed, current file:  sample_data/segments/dheem-b-066.wav
# 140 files processed, current file:  sample_data/segments/dheem-b-095.wav
# 160 files processed, current file:  sample_data/segments/dheem-b-116.wav
# 180 files processed, current file:  sample_data/segments/dhin-b-012.wav
# 200 files processed, current file:  sample_data/segments/dhin-b-040.wav
# 220 files processed, current file:  sample_data/segments/num-b-013.wav
# 240 files processed, current file:  sample_data/segments/num-b-037.wav
# 260 files processed, current file:  sample_data/segments/num-b-061.wav
# 280 files processed, current file:  sample_data/segments/ta-b-001.wav
# 300 files processed, current file:  sample_data/segments/ta-b-021.wav
# 320 files processed, current file:  sample_data/segments/ta-b-041.wav
# 340 files processed, current file:  sample_data/segments/ta-b-061.wav
# 360 files processed, current file:  sample_data/segments/ta-b-081.wav
# 380 files processed, current file:  sample_data/segments/ta-b-101.wav
# 400 files processed, current file:  sample_data/segments/ta-b-121.wav
# 420 files processed, current file:  sample_data/segments/ta-b-141.wav
# 440 files processed, current file:  sample_data/segments/tha-b-017.wav
# 460 files processed, current file:  sample_data/segments/tha-b-037.wav
# 480 files processed, current file:  sample_data/segments/tha-b-057.wav
# 500 files processed, current file:  sample_data/segments/tha-b-077.wav
# 520 files processed, current file:  sample_data/segments/tha-b-097.wav
# 540 files processed, current file:  sample_data/segments/tha-b-117.wav
# 560 files processed, current file:  sample_data/segments/tha-b-137.wav
# 580 files processed, current file:  sample_data/segments/tha-b-157.wav
# 600 files processed, current file:  sample_data/segments/tha-b-177.wav
# 620 files processed, current file:  sample_data/segments/tha-b-198.wav
# 640 files processed, current file:  sample_data/segments/tham-b-018.wav
# 660 files processed, current file:  sample_data/segments/tham-b-039.wav
# 680 files processed, current file:  sample_data/segments/tham-b-059.wav
# 700 files processed, current file:  sample_data/segments/tham-b-079.wav
# 720 files processed, current file:  sample_data/segments/thi-b-011.wav
# 740 files processed, current file:  sample_data/segments/thi-b-031.wav
# 760 files processed, current file:  sample_data/segments/thi-b-051.wav
# 780 files processed, current file:  sample_data/segments/thi-b-071.wav
# 800 files processed, current file:  sample_data/segments/thi-b-091.wav
# 820 files processed, current file:  sample_data/segments/thi-b-111.wav
# 840 files processed, current file:  sample_data/segments/thi-b-133.wav
# 860 files processed, current file:  sample_data/segments/thi-b-153.wav
# 880 files processed, current file:  sample_data/segments/thi-b-173.wav
# 900 files processed, current file:  sample_data/segments/thi-b-193.wav
# 920 files processed, current file:  sample_data/segments/thi-b-213.wav
# 940 files processed, current file:  sample_data/segments/thi-b-233.wav
# 960 files processed, current file:  sample_data/segments/thi-b-254.wav
# 980 files processed, current file:  sample_data/segments/thi-b-274.wav
# 1000 files processed, current file:  sample_data/segments/thi-b-294.wav
# 1020 files processed, current file:  sample_data/segments/thi-b-314.wav
# 1040 files processed, current file:  sample_data/segments/thi-b-334.wav
# 1060 files processed, current file:  sample_data/segments/thi-b-354.wav
# 1080 files processed, current file:  sample_data/segments/thi-b-374.wav
# 1100 files processed, current file:  sample_data/segments/thi-b-395.wav
# 1120 files processed, current file:  sample_data/segments/thi-b-417.wav
# 1140 files processed, current file:  sample_data/segments/thi-b-437.wav
# 1160 files processed, current file:  sample_data/segments/thom-b-019.wav
# 1180 files processed, current file:  sample_data/segments/thom-b-039.wav
# 1200 files processed, current file:  sample_data/segments/thom-b-061.wav
# 1220 files processed, current file:  sample_data/segments/thom-b-082.wav
# 1240 files processed, current file:  sample_data/segments/thom-b-105.wav
# 1260 files processed, current file:  sample_data/segments/thom-b-125.wav
# 1280 files processed, current file:  sample_data/segments/cha-c-007.wav
# 1300 files processed, current file:  sample_data/segments/cha-c-029.wav
# 1320 files processed, current file:  sample_data/segments/dheem-c-001.wav
# 1340 files processed, current file:  sample_data/segments/dheem-c-021.wav
# 1360 files processed, current file:  sample_data/segments/dheem-c-041.wav
# 1380 files processed, current file:  sample_data/segments/dheem-c-061.wav
# 1400 files processed, current file:  sample_data/segments/dheem-c-081.wav
# 1420 files processed, current file:  sample_data/segments/dhin-c-027.wav
# 1440 files processed, current file:  sample_data/segments/num-c-011.wav
# 1460 files processed, current file:  sample_data/segments/num-c-031.wav
# 1480 files processed, current file:  sample_data/segments/num-c-051.wav
# 1500 files processed, current file:  sample_data/segments/num-c-071.wav
# 1520 files processed, current file:  sample_data/segments/num-c-094.wav
# 1540 files processed, current file:  sample_data/segments/ta-c-016.wav
# 1560 files processed, current file:  sample_data/segments/ta-c-036.wav
# 1580 files processed, current file:  sample_data/segments/ta-c-056.wav
# 1600 files processed, current file:  sample_data/segments/ta-c-076.wav
# 1620 files processed, current file:  sample_data/segments/ta-c-096.wav
# 1640 files processed, current file:  sample_data/segments/ta-c-116.wav
# 1660 files processed, current file:  sample_data/segments/ta-c-136.wav
# 1680 files processed, current file:  sample_data/segments/ta-c-156.wav
# 1700 files processed, current file:  sample_data/segments/tha-c-011.wav
# 1720 files processed, current file:  sample_data/segments/tha-c-031.wav
# 1740 files processed, current file:  sample_data/segments/tha-c-051.wav
# 1760 files processed, current file:  sample_data/segments/tha-c-071.wav
# 1780 files processed, current file:  sample_data/segments/tha-c-091.wav
# 1800 files processed, current file:  sample_data/segments/tha-c-111.wav
# 1820 files processed, current file:  sample_data/segments/tha-c-131.wav
# 1840 files processed, current file:  sample_data/segments/tha-c-151.wav
# 1860 files processed, current file:  sample_data/segments/tha-c-171.wav
# 1880 files processed, current file:  sample_data/segments/tham-c-007.wav
# 1900 files processed, current file:  sample_data/segments/tham-c-028.wav
# 1920 files processed, current file:  sample_data/segments/tham-c-054.wav
# 1940 files processed, current file:  sample_data/segments/tham-c-074.wav
# 1960 files processed, current file:  sample_data/segments/thi-c-014.wav
# 1980 files processed, current file:  sample_data/segments/thi-c-034.wav
# 2000 files processed, current file:  sample_data/segments/thi-c-056.wav
# 2020 files processed, current file:  sample_data/segments/thi-c-082.wav
# 2040 files processed, current file:  sample_data/segments/thi-c-103.wav
# 2060 files processed, current file:  sample_data/segments/thi-c-123.wav
# 2080 files processed, current file:  sample_data/segments/thi-c-143.wav
# 2100 files processed, current file:  sample_data/segments/thi-c-163.wav
# 2120 files processed, current file:  sample_data/segments/thi-c-183.wav
# 2140 files processed, current file:  sample_data/segments/thi-c-203.wav
# 2160 files processed, current file:  sample_data/segments/thi-c-223.wav
# 2180 files processed, current file:  sample_data/segments/thi-c-243.wav
# 2200 files processed, current file:  sample_data/segments/thi-c-263.wav
# 2220 files processed, current file:  sample_data/segments/thi-c-283.wav
# 2240 files processed, current file:  sample_data/segments/thi-c-303.wav
# 2260 files processed, current file:  sample_data/segments/thi-c-323.wav
# 2280 files processed, current file:  sample_data/segments/thom-c-009.wav
# 2300 files processed, current file:  sample_data/segments/thom-c-030.wav
# 2320 files processed, current file:  sample_data/segments/thom-c-050.wav
# 2340 files processed, current file:  sample_data/segments/thom-c-070.wav
# 2360 files processed, current file:  sample_data/segments/cha-csh-012.wav
# 2380 files processed, current file:  sample_data/segments/cha-csh-042.wav
# 2400 files processed, current file:  sample_data/segments/dheem-csh-012.wav
# 2420 files processed, current file:  sample_data/segments/dheem-csh-034.wav
# 2440 files processed, current file:  sample_data/segments/dheem-csh-055.wav
# 2460 files processed, current file:  sample_data/segments/dheem-csh-076.wav
# 2480 files processed, current file:  sample_data/segments/num-csh-004.wav
# 2500 files processed, current file:  sample_data/segments/num-csh-024.wav
# 2520 files processed, current file:  sample_data/segments/num-csh-044.wav
# 2540 files processed, current file:  sample_data/segments/num-csh-064.wav
# 2560 files processed, current file:  sample_data/segments/num-csh-087.wav
# 2580 files processed, current file:  sample_data/segments/ta-csh-010.wav
# 2600 files processed, current file:  sample_data/segments/ta-csh-030.wav
# 2620 files processed, current file:  sample_data/segments/ta-csh-052.wav
# 2640 files processed, current file:  sample_data/segments/ta-csh-072.wav
# 2660 files processed, current file:  sample_data/segments/ta-csh-092.wav
# 2680 files processed, current file:  sample_data/segments/ta-csh-112.wav
# 2700 files processed, current file:  sample_data/segments/ta-csh-133.wav
# 2720 files processed, current file:  sample_data/segments/ta-csh-153.wav
# 2740 files processed, current file:  sample_data/segments/ta-csh-174.wav
# 2760 files processed, current file:  sample_data/segments/ta-csh-194.wav
# 2780 files processed, current file:  sample_data/segments/ta-csh-214.wav
# 2800 files processed, current file:  sample_data/segments/tha-csh-017.wav
# 2820 files processed, current file:  sample_data/segments/tha-csh-037.wav
# 2840 files processed, current file:  sample_data/segments/tha-csh-057.wav
# 2860 files processed, current file:  sample_data/segments/tha-csh-078.wav
# 2880 files processed, current file:  sample_data/segments/tha-csh-104.wav
# 2900 files processed, current file:  sample_data/segments/tha-csh-124.wav
# 2920 files processed, current file:  sample_data/segments/tha-csh-145.wav
# 2940 files processed, current file:  sample_data/segments/tha-csh-165.wav
# 2960 files processed, current file:  sample_data/segments/tha-csh-185.wav
# 2980 files processed, current file:  sample_data/segments/tha-csh-205.wav
# 3000 files processed, current file:  sample_data/segments/tham-csh-014.wav
# 3020 files processed, current file:  sample_data/segments/thi-csh-002.wav
# 3040 files processed, current file:  sample_data/segments/thi-csh-023.wav
# 3060 files processed, current file:  sample_data/segments/thi-csh-043.wav
# 3080 files processed, current file:  sample_data/segments/thi-csh-063.wav
# 3100 files processed, current file:  sample_data/segments/thi-csh-086.wav
# 3120 files processed, current file:  sample_data/segments/thi-csh-107.wav
# 3140 files processed, current file:  sample_data/segments/thi-csh-127.wav
# 3160 files processed, current file:  sample_data/segments/thi-csh-148.wav
# 3180 files processed, current file:  sample_data/segments/thi-csh-168.wav
# 3200 files processed, current file:  sample_data/segments/thi-csh-188.wav
# 3220 files processed, current file:  sample_data/segments/thi-csh-208.wav
# 3240 files processed, current file:  sample_data/segments/thi-csh-229.wav
# 3260 files processed, current file:  sample_data/segments/thi-csh-250.wav
# 3280 files processed, current file:  sample_data/segments/thi-csh-277.wav
# 3300 files processed, current file:  sample_data/segments/thi-csh-300.wav
# 3320 files processed, current file:  sample_data/segments/thi-csh-321.wav
# 3340 files processed, current file:  sample_data/segments/thi-csh-341.wav
# 3360 files processed, current file:  sample_data/segments/thi-csh-361.wav
# 3380 files processed, current file:  sample_data/segments/thom-csh-012.wav
# 3400 files processed, current file:  sample_data/segments/thom-csh-033.wav
# 3420 files processed, current file:  sample_data/segments/thom-csh-053.wav
# 3440 files processed, current file:  sample_data/segments/cha-d-005.wav
# 3460 files processed, current file:  sample_data/segments/cha-d-025.wav
# 3480 files processed, current file:  sample_data/segments/cha-d-050.wav
# 3500 files processed, current file:  sample_data/segments/dheem-d-007.wav
# 3520 files processed, current file:  sample_data/segments/num-d-013.wav
# 3540 files processed, current file:  sample_data/segments/ta-d-015.wav
# 3560 files processed, current file:  sample_data/segments/ta-d-035.wav
# 3580 files processed, current file:  sample_data/segments/ta-d-055.wav
# 3600 files processed, current file:  sample_data/segments/ta-d-076.wav
# 3620 files processed, current file:  sample_data/segments/ta-d-096.wav
# 3640 files processed, current file:  sample_data/segments/ta-d-116.wav
# 3660 files processed, current file:  sample_data/segments/ta-d-138.wav
# 3680 files processed, current file:  sample_data/segments/ta-d-158.wav
# 3700 files processed, current file:  sample_data/segments/ta-d-178.wav
# 3720 files processed, current file:  sample_data/segments/tha-d-018.wav
# 3740 files processed, current file:  sample_data/segments/tha-d-038.wav
# 3760 files processed, current file:  sample_data/segments/tha-d-065.wav
# 3780 files processed, current file:  sample_data/segments/tha-d-086.wav
# 3800 files processed, current file:  sample_data/segments/tha-d-106.wav
# 3820 files processed, current file:  sample_data/segments/tha-d-129.wav
# 3840 files processed, current file:  sample_data/segments/tha-d-149.wav
# 3860 files processed, current file:  sample_data/segments/tha-d-169.wav
# 3880 files processed, current file:  sample_data/segments/tha-d-189.wav
# 3900 files processed, current file:  sample_data/segments/tha-d-210.wav
# 3920 files processed, current file:  sample_data/segments/tham-d-010.wav
# 3940 files processed, current file:  sample_data/segments/thi-d-002.wav
# 3960 files processed, current file:  sample_data/segments/thi-d-022.wav
# 3980 files processed, current file:  sample_data/segments/thi-d-042.wav
# 4000 files processed, current file:  sample_data/segments/thi-d-069.wav
# 4020 files processed, current file:  sample_data/segments/thi-d-089.wav
# 4040 files processed, current file:  sample_data/segments/thi-d-109.wav
# 4060 files processed, current file:  sample_data/segments/thi-d-129.wav
# 4080 files processed, current file:  sample_data/segments/thi-d-149.wav
# 4100 files processed, current file:  sample_data/segments/thi-d-169.wav
# 4120 files processed, current file:  sample_data/segments/thi-d-189.wav
# 4140 files processed, current file:  sample_data/segments/thi-d-209.wav
# 4160 files processed, current file:  sample_data/segments/thi-d-230.wav
# 4180 files processed, current file:  sample_data/segments/thi-d-250.wav
# 4200 files processed, current file:  sample_data/segments/thi-d-270.wav
# 4220 files processed, current file:  sample_data/segments/thom-d-007.wav
# 4240 files processed, current file:  sample_data/segments/thom-d-027.wav
# 4260 files processed, current file:  sample_data/segments/thom-d-049.wav
# 4280 files processed, current file:  sample_data/segments/thom-d-069.wav
# 4300 files processed, current file:  sample_data/segments/thom-d-090.wav
# 4320 files processed, current file:  sample_data/segments/cha-dsh-005.wav
# 4340 files processed, current file:  sample_data/segments/cha-dsh-025.wav
# 4360 files processed, current file:  sample_data/segments/cha-dsh-046.wav
# 4380 files processed, current file:  sample_data/segments/dheem-dsh-017.wav
# 4400 files processed, current file:  sample_data/segments/dheem-dsh-037.wav
# 4420 files processed, current file:  sample_data/segments/dheem-dsh-058.wav
# 4440 files processed, current file:  sample_data/segments/dheem-dsh-078.wav
# 4460 files processed, current file:  sample_data/segments/dheem-dsh-098.wav
# 4480 files processed, current file:  sample_data/segments/dhin-dsh-007.wav
# 4500 files processed, current file:  sample_data/segments/dhin-dsh-027.wav
# 4520 files processed, current file:  sample_data/segments/dhin-dsh-047.wav
# 4540 files processed, current file:  sample_data/segments/dhin-dsh-067.wav
# 4560 files processed, current file:  sample_data/segments/dhin-dsh-089.wav
# 4580 files processed, current file:  sample_data/segments/dhin-dsh-109.wav
# 4600 files processed, current file:  sample_data/segments/dhin-dsh-129.wav
# 4620 files processed, current file:  sample_data/segments/dhin-dsh-149.wav
# 4640 files processed, current file:  sample_data/segments/dhin-dsh-169.wav
# 4660 files processed, current file:  sample_data/segments/dhin-dsh-189.wav
# 4680 files processed, current file:  sample_data/segments/num-dsh-011.wav
# 4700 files processed, current file:  sample_data/segments/num-dsh-031.wav
# 4720 files processed, current file:  sample_data/segments/num-dsh-051.wav
# 4740 files processed, current file:  sample_data/segments/num-dsh-071.wav
# 4760 files processed, current file:  sample_data/segments/num-dsh-091.wav
# 4780 files processed, current file:  sample_data/segments/num-dsh-111.wav
# 4800 files processed, current file:  sample_data/segments/num-dsh-131.wav
# 4820 files processed, current file:  sample_data/segments/ta-dsh-008.wav
# 4840 files processed, current file:  sample_data/segments/ta-dsh-028.wav
# 4860 files processed, current file:  sample_data/segments/ta-dsh-048.wav
# 4880 files processed, current file:  sample_data/segments/ta-dsh-068.wav
# 4900 files processed, current file:  sample_data/segments/ta-dsh-089.wav
# 4920 files processed, current file:  sample_data/segments/ta-dsh-109.wav
# 4940 files processed, current file:  sample_data/segments/tha-dsh-012.wav
# 4960 files processed, current file:  sample_data/segments/tha-dsh-032.wav
# 4980 files processed, current file:  sample_data/segments/tha-dsh-055.wav
# 5000 files processed, current file:  sample_data/segments/tha-dsh-075.wav
# 5020 files processed, current file:  sample_data/segments/tha-dsh-096.wav
# 5040 files processed, current file:  sample_data/segments/tha-dsh-116.wav
# 5060 files processed, current file:  sample_data/segments/tha-dsh-136.wav
# 5080 files processed, current file:  sample_data/segments/tha-dsh-156.wav
# 5100 files processed, current file:  sample_data/segments/tha-dsh-176.wav
# 5120 files processed, current file:  sample_data/segments/tham-dsh-002.wav
# 5140 files processed, current file:  sample_data/segments/tham-dsh-022.wav
# 5160 files processed, current file:  sample_data/segments/tham-dsh-042.wav
# 5180 files processed, current file:  sample_data/segments/tham-dsh-062.wav
# 5200 files processed, current file:  sample_data/segments/tham-dsh-083.wav
# 5220 files processed, current file:  sample_data/segments/thi-dsh-011.wav
# 5240 files processed, current file:  sample_data/segments/thi-dsh-031.wav
# 5260 files processed, current file:  sample_data/segments/thi-dsh-051.wav
# 5280 files processed, current file:  sample_data/segments/thi-dsh-071.wav
# 5300 files processed, current file:  sample_data/segments/thi-dsh-091.wav
# 5320 files processed, current file:  sample_data/segments/thi-dsh-111.wav
# 5340 files processed, current file:  sample_data/segments/thi-dsh-132.wav
# 5360 files processed, current file:  sample_data/segments/thi-dsh-152.wav
# 5380 files processed, current file:  sample_data/segments/thi-dsh-172.wav
# 5400 files processed, current file:  sample_data/segments/thi-dsh-192.wav
# 5420 files processed, current file:  sample_data/segments/thi-dsh-215.wav
# 5440 files processed, current file:  sample_data/segments/thi-dsh-235.wav
# 5460 files processed, current file:  sample_data/segments/thi-dsh-255.wav
# 5480 files processed, current file:  sample_data/segments/thi-dsh-278.wav
# 5500 files processed, current file:  sample_data/segments/thi-dsh-298.wav
# 5520 files processed, current file:  sample_data/segments/thi-dsh-318.wav
# 5540 files processed, current file:  sample_data/segments/thi-dsh-338.wav
# 5560 files processed, current file:  sample_data/segments/thi-dsh-358.wav
# 5580 files processed, current file:  sample_data/segments/thi-dsh-378.wav
# 5600 files processed, current file:  sample_data/segments/thi-dsh-400.wav
# 5620 files processed, current file:  sample_data/segments/thi-dsh-420.wav
# 5640 files processed, current file:  sample_data/segments/thi-dsh-440.wav
# 5660 files processed, current file:  sample_data/segments/thom-dsh-017.wav
# 5680 files processed, current file:  sample_data/segments/thom-dsh-038.wav
# 5700 files processed, current file:  sample_data/segments/thom-dsh-060.wav
# 5720 files processed, current file:  sample_data/segments/thom-dsh-081.wav
# 5740 files processed, current file:  sample_data/segments/thom-dsh-110.wav
# 5760 files processed, current file:  sample_data/segments/bheem-e-003.wav
# 5780 files processed, current file:  sample_data/segments/bheem-e-023.wav
# 5800 files processed, current file:  sample_data/segments/cha-e-018.wav
# 5820 files processed, current file:  sample_data/segments/cha-e-038.wav
# 5840 files processed, current file:  sample_data/segments/dheem-e-005.wav
# 5860 files processed, current file:  sample_data/segments/dheem-e-025.wav
# 5880 files processed, current file:  sample_data/segments/dheem-e-045.wav
# 5900 files processed, current file:  sample_data/segments/dhin-e-011.wav
# 5920 files processed, current file:  sample_data/segments/dhin-e-031.wav
# 5940 files processed, current file:  sample_data/segments/dhin-e-051.wav
# 5960 files processed, current file:  sample_data/segments/dhin-e-071.wav
# 5980 files processed, current file:  sample_data/segments/dhin-e-091.wav
# 6000 files processed, current file:  sample_data/segments/dhin-e-111.wav
# 6020 files processed, current file:  sample_data/segments/num-e-018.wav
# 6040 files processed, current file:  sample_data/segments/num-e-039.wav
# 6060 files processed, current file:  sample_data/segments/num-e-059.wav
# 6080 files processed, current file:  sample_data/segments/ta-e-019.wav
# 6100 files processed, current file:  sample_data/segments/ta-e-039.wav
# 6120 files processed, current file:  sample_data/segments/ta-e-059.wav
# 6140 files processed, current file:  sample_data/segments/ta-e-079.wav
# 6160 files processed, current file:  sample_data/segments/ta-e-099.wav
# 6180 files processed, current file:  sample_data/segments/tha-e-014.wav
# 6200 files processed, current file:  sample_data/segments/tha-e-034.wav
# 6220 files processed, current file:  sample_data/segments/tha-e-054.wav
# 6240 files processed, current file:  sample_data/segments/tha-e-074.wav
# 6260 files processed, current file:  sample_data/segments/tha-e-094.wav
# 6280 files processed, current file:  sample_data/segments/tha-e-114.wav
# 6300 files processed, current file:  sample_data/segments/tha-e-134.wav
# 6320 files processed, current file:  sample_data/segments/tha-e-155.wav
# 6340 files processed, current file:  sample_data/segments/tham-e-015.wav
# 6360 files processed, current file:  sample_data/segments/tham-e-035.wav
# 6380 files processed, current file:  sample_data/segments/thi-e-005.wav
# 6400 files processed, current file:  sample_data/segments/thi-e-025.wav
# 6420 files processed, current file:  sample_data/segments/thi-e-046.wav
# 6440 files processed, current file:  sample_data/segments/thi-e-066.wav
# 6460 files processed, current file:  sample_data/segments/thi-e-086.wav
# 6480 files processed, current file:  sample_data/segments/thi-e-106.wav
# 6500 files processed, current file:  sample_data/segments/thi-e-126.wav
# 6520 files processed, current file:  sample_data/segments/thi-e-146.wav
# 6540 files processed, current file:  sample_data/segments/thi-e-166.wav
# 6560 files processed, current file:  sample_data/segments/thi-e-186.wav
# 6580 files processed, current file:  sample_data/segments/thi-e-206.wav
# 6600 files processed, current file:  sample_data/segments/thi-e-226.wav
# 6620 files processed, current file:  sample_data/segments/thi-e-246.wav
# 6640 files processed, current file:  sample_data/segments/thi-e-266.wav
# 6660 files processed, current file:  sample_data/segments/thi-e-286.wav
# 6680 files processed, current file:  sample_data/segments/thi-e-306.wav
# 6700 files processed, current file:  sample_data/segments/thi-e-326.wav
# 6720 files processed, current file:  sample_data/segments/thom-e-001.wav
# 6740 files processed, current file:  sample_data/segments/thom-e-021.wav
# 6760 files processed, current file:  sample_data/segments/thom-e-041.wav
# 6780 files processed, current file:  sample_data/segments/thom-e-061.wav
# 6800 files processed, current file:  sample_data/segments/thom-e-081.wav
# 6820 files processed, current file:  sample_data/segments/thom-e-101.wav
# 6840 files processed, current file:  sample_data/segments/thom-e-121.wav
# A total of  6854 files processed

# %%
#Read data with pandas module
data = pd.read_csv(data_file)

#Plot first lines of our data
data.head()
# Out:
#    chords_changes_rate  chords_number_rate  chords_strength.max  \
# 0                  0.0            0.071429             0.447176
# 1                  0.0            0.090909             0.463626
# 2                  0.0            0.125000             0.463614
# 3                  0.0            0.071429             0.579307
# 4                  0.0            0.200000             0.415426
#
#    chords_strength.mean  chords_strength.median  chords_strength.min  \
# 0              0.447176                0.447176             0.447176
# 1              0.463626                0.463626             0.463626
# 2              0.463614                0.463614             0.463614
# 3              0.579307                0.579307             0.579307
# 4              0.415426                0.415426             0.415426
#
#    chords_strength.var  hpcp_crest.max  hpcp_crest.mean  hpcp_crest.median  \
# 0         0.000000e+00       17.848509        13.688197          14.187656
# 1         0.000000e+00       17.964497        13.578070          17.529263
# 2         8.881784e-16       17.847248        13.411448          12.557196
# 3         3.552714e-15       17.782604        11.860773          11.562714
# 4         0.000000e+00       33.744499        19.634932          17.648977
#
#    ...  hpcp_entropy.min  hpcp_entropy.var  key_edma.strength  \
# 0  ...          1.073985          0.578526           0.617265
# 1  ...          1.072875          0.891260           0.616398
# 2  ...          1.075361          0.160865           0.619288
# 3  ...          1.102663          0.291535           0.587788
# 4  ...          0.367357          0.550065           0.580428
#
#    key_krumhansl.strength  key_temperley.strength  tuning_diatonic_strength  \
# 0                0.605408                0.579266                  0.418163
# 1                0.604717                0.578948                  0.342059
# 2                0.607534                0.581673                  0.410444
# 3                0.578079                0.556459                  0.433545
# 4                0.571059                0.555848                  0.453090
#
#    tuning_equal_tempered_deviation  tuning_frequency  \
# 0                         0.190164        435.952271
# 1                         0.225905        434.946167
# 2                         0.252750        434.946167
# 3                         0.241954        432.690918
# 4                         0.184925        440.000000
#
#    tuning_nontempered_energy_ratio  tonic
# 0                         0.783505      b
# 1                         0.813583      b
# 2                         0.804092      b
# 3                         0.892127      b
# 4                         0.800189      b
#
# [5 rows x 25 columns]

# %%
# Take two random features and plot the sample points
import seaborn as sns
# The features are now TONIC rather than LOW LEVEL, so the plot is changed accordingly
sns.relplot(x = "hpcp_crest.median", y = "tuning_frequency", hue = "tonic", data = data);

# %% [markdown]
# ### Preprocessing of the features

# %%
data_modif = data.copy()

#Let's use sklearn's preprocessing tools for applying normalisation to features
from sklearn import preprocessing
# Scale everything between 0 and 1 (data normalization)
min_max_scaler = preprocessing.MinMaxScaler()
# The number of features also changes, not 85 anymore, but only 24
data_modif.iloc[:,:24] = min_max_scaler.fit_transform(data.iloc[:,:24].values)

# %%
# Checking if our data is balanced (if not, we should balance it to prevent our model to be baised)
# Balance data, in a classification task, tends to have the same amount of training examples for each label
# https://en.wikipedia.org/wiki/Oversampling_and_undersampling_in_data_analysis
data_modif.tonic.value_counts()
# Out:
# dsh    1456
# b      1271
# e      1097
# csh    1086
# c      1079
# d       865
# Name: tonic, dtype: int64

# %%
# Here we didn't pick the lowest number, 865 for D, which is too small.
# Instead, we choose the 1079 of C
# Label D will be oversampled, C is untouched, all others will be downsampled

# We use pandas.DataFrame.sample()

min_number = data_modif.tonic.value_counts()['c']
print(f'All data will be randomly re-sampled with {min_number} values')

dsh_data = data_modif[data_modif.tonic == 'dsh'].sample(n = min_number, random_state = 42)
b_data = data_modif[data_modif.tonic == 'b'].sample(n = min_number)
e_data = data_modif[data_modif.tonic == 'e'].sample(n = min_number)
csh_data = data_modif[data_modif.tonic == 'csh'].sample(n = min_number)
c_data = data_modif[data_modif.tonic == 'c'].sample(n = min_number)
# Probably I shouldn't oversample D ? Let's see....
d_data = data_modif[data_modif.tonic == 'd'].sample(n = min_number, replace=True)

#Merging after downsampling
data_modif = pd.concat([dsh_data, b_data, e_data, csh_data, c_data, d_data])
#Checking the balance again
print(data_modif.tonic.value_counts())
# Out:
# All data will be randomly re-sampled with 1079 values
# dsh    1079
# b      1079
# e      1079
# csh    1079
# c      1079
# d      1079
# Name: tonic, dtype: int64

# %% [markdown]
# ## Supervised learning approach (Support Vector Machines)

# %%
# Input values put in a matrix, there are 84 features
X = data_modif.iloc[:,:24].values 
# Creating output values
data_modif.tonic = pd.Categorical(data_modif.tonic)  # convert to categorical data
y = np.array(data_modif.tonic.cat.codes)  # create label encoded outputs
# Print the first sample
print("Features of the first sample: ", X[0])
print("Class of the first sample: ", y[0])
# Out:
# Features of the first sample:  [0.00000000e+00 1.00000000e+00 7.65340921e-01 7.65340921e-01
#  7.65340921e-01 7.65340921e-01 0.00000000e+00 1.56312491e-01
#  1.45767191e-01 1.51015133e-01 1.86873911e-01 1.32875145e-03
#  5.55691597e-01 6.47798444e-01 6.51479464e-01 6.80201038e-01
#  9.03235451e-04 5.20102277e-01 5.17866195e-01 5.10127368e-01
#  3.40622655e-01 5.88380902e-01 2.67081724e-01 7.57805563e-01]
# Class of the first sample:  4

# %%
# Let's split data into test and train sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# Check sizes of input and output vectors
print("Size of train features matrix: ",X_train.shape, ", Size of train output vector: ",y_train.shape)
print("Size of test features matrix: ",X_test.shape, ", Size of test output vector: ",y_test.shape)
# Out:
# Size of train features matrix:  (4337, 24) , Size of train output vector:  (4337,)
# Size of test features matrix:  (2137, 24) , Size of test output vector:  (2137,)

# %%
# Define and train the model

from sklearn import svm
clf = svm.SVC(gamma = 1 / (X_train.shape[-1] * X_train.var()))

# Fit model with training data
clf.fit(X_train, y_train)

# Predict classes of test samples
y_pred = clf.predict(X_test)

# %%
# Test the model
# Let's check for each sample in the test set if prediction matches the true class information
y_test == y_pred
# Out:
# array([ True, False,  True, ...,  True,  True,  True])

# %%
# Data is balanced, so you can use accuracy as a measure:
print("accuracy: ", np.sum(y_test == y_pred)/len(y_test))

# ACCURACY IS MUCH LOWER THAN WITH LOW LEVEL FEATURES (0.35 rather than 0.65)
# Out:
# accuracy:  0.3575105287786617

# %%
# Print the confusion matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns

classes = np.unique(data_modif.tonic)
conf_mat = pd.DataFrame(confusion_matrix(y_test, y_pred), columns = classes, index = classes)
conf_mat.index.name = 'Actual'
conf_mat.columns.name = 'Predicted'
plt.figure(figsize = (7, 5))
sns.set(font_scale = 1.2)
sns.heatmap(conf_mat, cmap = "Blues", annot_kws = {"size": 12}, annot = True);

# %% [markdown]
# ## Supervised learning approach (Neural Network)

# %%
from sklearn.preprocessing import StandardScaler

# Let's start by splitting our data 
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size = 0.20, random_state = 1)

# ..and apply normalisation
scaler = StandardScaler().fit(X_train_val)
norm_x_train_val = scaler.transform(X_train_val)
norm_x_test = scaler.transform(X_test)

# %%
from sklearn.preprocessing import OneHotEncoder
onehot_encoder = OneHotEncoder(sparse=False)
y_train_val_onehot = onehot_encoder.fit_transform(y_train_val.reshape(len(y_train_val), 1))
y_test_onehot = onehot_encoder.fit_transform(y_test.reshape(len(y_test), 1))
print("One-hot encoded y_train_val shape = ", y_train_val_onehot.shape)
print("One-hot encoded y_test shape = ", y_test_onehot.shape)
# Out:
# One-hot encoded y_train_val shape =  (5179, 6)
# One-hot encoded y_test shape =  (1295, 6)

# %%
from keras.models import Sequential
from keras import layers

'''
Keras is a library built on top of TensorFlow 2
https://keras.io/guides/sequential_model/

A Sequential model is appropriate for a plain stack of layers
where each layer has exactly one input tensor and one output tensor.
'''

def compose_model(num_features):
    
    model = Sequential()
    # HERE I MADE SOME CHANGES TO THE NUMBER OF NEURONS IN LAYER 1 and 2
    # THE NUMBER OF NEURONS IN LAYER 1 ARE EQUAL TO THE NUMBER OF TONAL FEATURES (25)

    # Input layer 
    model.add(layers.BatchNormalization(name='InputLayer', input_shape=(num_features,)))
    
    # 1. hidden layer
    model.add(layers.Dense(name='HiddenLayer_1', units = 12)) # approximately a half neurons than input layer
    model.add(layers.BatchNormalization())
    model.add(layers.Activation('tanh'))
    model.add(layers.Dropout(0.3))

    '''
    # If every layer halves the number of neurons of the preceeding layer, we should not have this hidden layer in this model
    # 2. hidden layer
    model.add(layers.Dense(name='HiddenLayer_2', units = 15))
    model.add(layers.BatchNormalization())
    model.add(layers.Activation('relu'))
    model.add(layers.Dropout(0.3))
    '''

    # Output layer
    # THIS HAS BEEN MODIFIED BECAUSE WE HAVE 6 LABELS (tonics) RATHER THAN 10 (strokes)
    model.add(layers.Dense(name='Output_layer', units = 6))
    model.add(layers.Activation('sigmoid'))
    
    return model

model = compose_model(X_train_val.shape[1])

# %%
model.summary()  # Plot summary of the model
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  InputLayer (BatchNormalizat  (None, 24)               96
#  ion)
#
#  HiddenLayer_1 (Dense)       (None, 25)                625
#
#  batch_normalization_4 (Batc  (None, 25)               100
#  hNormalization)
#
#  activation_6 (Activation)   (None, 25)                0
#
#  dropout_4 (Dropout)         (None, 25)                0
#
#  HiddenLayer_2 (Dense)       (None, 15)                390
#
#  batch_normalization_5 (Batc  (None, 15)               60
#  hNormalization)
#
#  activation_7 (Activation)   (None, 15)                0
#
#  dropout_5 (Dropout)         (None, 15)                0
#
#  Output_layer (Dense)        (None, 6)                 96
#
#  activation_8 (Activation)   (None, 6)                 0
#
# =================================================================
# Total params: 1,367
# Trainable params: 1,239
# Non-trainable params: 128
# _________________________________________________________________

# %%
model.compile(optimizer = 'Adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
summary = model.fit(X_train_val, y_train_val_onehot, batch_size = 50, epochs = 250, validation_split=0.2, verbose=0)

# %%
score = model.evaluate(X_test, y_test_onehot, verbose = 0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

'''
DATA WITH LOW LEVEL FEATURES (MUCH BETER THAN THIS ONE, which uses tonic features);
Test loss: 0.19820061326026917
Test accuracy: 0.7312741279602051
'''
# Out:
# Test loss: 0.38967135548591614
# Test accuracy: 0.3922779858112335
# '\nDATA WITH LOW LEVEL FEATURES (MUCH BETER THAN THIS ONE, which uses tonic features);\nTest loss: 0.19820061326026917\nTest accuracy: 0.7312741279602051\n'

# %%
# summarize history for accuracy
plt.plot(summary.history['accuracy'])
plt.plot(summary.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower right')
plt.show()
# summarize history for loss
plt.plot(summary.history['loss'])
plt.plot(summary.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()
